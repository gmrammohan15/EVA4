# %% [markdown]
# <a href="https://colab.research.google.com/github/gmrammohan15/EVA4/blob/master/S13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/gmrammohan15/EVA4.git
# Out:
# Cloning into 'EVA4'...
# remote: Enumerating objects: 1760, done.
# remote: Counting objects: 100% (1760/1760), done.
# remote: Compressing objects: 100% (716/716), done.
# remote: Total 2100 (delta 39), reused 1721 (delta 13), pack-reused 340
# Receiving objects: 100% (2100/2100), 25.38 MiB | 21.42 MiB/s, done.
# Resolving deltas: 100% (218/218), done.

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# !ls
# !cd EVA4/
# Out:
# EVA4  gdrive  sample_data

# %%
# !pwd
# %cd cd /content/gdrive/My Drive/YoloV3

# %%
# %pwd
# !ls
# Out:
# gdrive	sample_data

# %%
# %cd gdrive/My Drive/
# Out:
# /content/gdrive/My Drive

# %%
# %cd YoloV3
# Out:
# /content/gdrive/My Drive/YoloV3

# %%
import sys
sys.path.append('/content/gdrive/My Drive/YoloV3')

# %%
import time
import glob
import torch
import os

from IPython.display import Image, clear_output 
print('PyTorch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# PyTorch 1.4.0 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15079MB, multi_processor_count=40)

# %%
# !pwd
# %cd YoloV3

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 300
# Out:
# Namespace(accumulate=4, adam=False, batch_size=10, bucket='', cache_images=True, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', device='', epochs=300, evolve=False, img_size=[512], multi_scale=False, name='', nosave=False, notest=False, rect=False, resume=False, single_cls=False, weights='weights/yolov3-spp-ultralytics.pt')
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15079MB)
#
# 2020-04-25 07:04:33.189050: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# Run 'tensorboard --logdir=runs' to view tensorboard at http://localhost:6006/
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# Caching labels (513 found, 0 missing, 0 empty, 0 duplicate, for 513 images): 100% 513/513 [05:16<00:00,  1.62it/s]
# Caching images (0.3GB): 100% 513/513 [06:00<00:00,  1.42it/s]
# Reading image shapes: 100% 513/513 [00:00<00:00, 1041.09it/s]
# ...
